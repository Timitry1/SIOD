# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

class HashTable:
    def __init__(self, capacity: int):
        self.capacity = capacity
        self.buckets = [[] for _ in range(capacity)]

    def get_hash(self, key):
        if key % self.capacity != key:
            raise KeyError("Не найдено")
        else:
            return key

    def add(self, key, value):
        index = self.get_hash(key)
        for k, v in self.buckets[index]:
            if k == key:
                v.append(value)
                return
        self.buckets[index].append((key, [value]))

    def find(self, key):
        index = self.get_hash(key)
        for k, v in self.buckets[index]:
            if k == key:
                return v
        return None

    def remove(self, key):
        index = self.get_hash(key)
        bucket = self.buckets[index]
        for i, (k, v) in enumerate(bucket):
            if k == key:
                del bucket[i]
                return
        raise KeyError("Не найден")

    def search(self, key):
        index = self.get_hash(key)
        for k, v in self.buckets[index]:
            if k == key:
                return True
        return False

def selection_sort(arr, key):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j][key] < arr[min_index][key]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

def read_data(file_name='orders.csv'):
    data = []
    try:
        with open(file_name, 'r', newline='', encoding='utf-8') as csvfile:
            csvreader = csv.reader(csvfile)
            next(csvreader)
            for row in csvreader:
                data.append(row)
        return data
    except Exception as e:
        print(f"Ошибка чтения файла - {file_name}: {str(e)}")
        return []

def show_csv_table(file='orders.csv'):
    try:
        df = pd.read_csv(file)
        df.index = [''] * len(df['Номер заказа'])
        display(df)
    except Exception as e:
        print(f"Проблемы с чтением файла - {file}: {str(e)}")

def show_table(data, length=1):
    df = pd.DataFrame(data)
    df.index = [''] * length
    display(df)

def pd_read_data(file='orders.csv'):
    try:
        df = pd.read_csv(file)
        return df
    except Exception as e:
        print(f"Проблема с чтением файла - {file} с помощью pandas: {str(e)}")

def search_the_most_selled_product(self) -> list:
    max_selled = max(int(product[4]) for product in self.data)
    max_selled_products = [product[2] for product in self.data if int(product[4]) == max_selled]
    return max_selled_products

file_name = 'orders.csv'
sales_data = read_data(file_name)

sales_data_dict = [dict(zip(['order_columns', 'order_date', 'name', 'category', 'count', 'price', 'price_all'], row)) for row in sales_data]

sorted_sales_data = selection_sort(sales_data_dict, 'order_date')

show_table(sorted_sales_data, len(sorted_sales_data))

total_revenue = sum(float(row['price_all']) for row in sales_data_dict)
print(f"Общая выручка магазина: {total_revenue}")

product_count = {}
for row in sales_data_dict:
    product = row['name']
    count = int(row['count'])
    if product in product_count:
        product_count[product] += count
    else:
        product_count[product] = count

most_sold_product = max(product_count, key=product_count.get)
print(f"Товар, который был продан наибольшее количество раз: {most_sold_product}")

product_revenue = {}
for row in sales_data_dict:
    product = row['name']
    revenue = float(row['price_all'])
    if product in product_revenue:
        product_revenue[product] += revenue
    else:
        product_revenue[product] = revenue

highest_revenue_product = max(product_revenue, key=product_revenue.get)
print(f"Товар, который принес наибольшую выручку: {highest_revenue_product}")

products = list(product_revenue.keys())
revenues = list(product_revenue.values())

plt.bar(products, revenues)
plt.xlabel('Товар')
plt.ylabel('Выручка')
plt.title('Распределение выручки по товарам')
plt.xticks(rotation=90)
plt.show()

plt.pie(revenues, labels=products, autopct='%1.1f%%')
plt.title('Распределение выручки по товарам')
plt.show()
# Out:
#  order_columns  order_date                                              name  \
#              1  2024-05-17                          Наушники Sony WH-1000XM4
#              2  2024-05-17                     Ноутбук ASUS ROG Zephyrus G14
#              3  2024-05-17  Пылесос-робот Xiaomi Mi Robot Vacuum-Mop 2 Pro +
#              4  2024-05-17            Монитор игровой LG UltraGear 27GP850-B
#              5  2024-05-17                   Смарт-часы Apple Watch Series 7
#              6  2024-05-17                         Блендер Philips HR3652/00
#              7  2024-05-17                   Фитнес-браслет Xiaomi Mi Band 6
#              8  2024-05-17                  Мобильный телефон Nokia C20 Plus
#              9  2024-05-17        Игровая приставка Sony PlayStation 5 (PS5)
#             10  2024-05-17                     Планшет Samsung Galaxy Tab S8
#             11  2024-05-17                          Фотоаппарат Canon EOS R5
#             12  2024-05-17                Кофемашина De'Longhi ECAM 350.35.W
#             13  2024-05-17                     Мультиварка REDMOND RMC-M4510
#             14  2024-05-17                                 Утюг Tefal FV5778
#
#             category count   price price_all
#             Наушники     5   29990    149950
#             Ноутбуки    10   89999    899990
#             Пылесосы    12   24990    299880
#             Мониторы     8   34999    279992
#           Умные часы    15   47990    719850
#     Кухонные приборы     4    6990     27960
#       Фитнес-трекеры    25    3490     87250
#   Мобильные телефоны    17    6990    118830
#    Игровые приставки     9   44990    404910
#             Планшеты     6   57990    347940
#         Фотоаппараты     3  249990    749970
#           Кофемашины     7   39990    279930
#          Мультиварки    11    7999     87989
#                Утюги     8    2999     23992
# Общая выручка магазина: 4478433.0
# Товар, который был продан наибольшее количество раз: Фитнес-браслет Xiaomi Mi Band 6
# Товар, который принес наибольшую выручку: Ноутбук ASUS ROG Zephyrus G14
